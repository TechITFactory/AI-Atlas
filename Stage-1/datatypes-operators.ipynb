# %%
print("hello")
# Out:
# hello

# %%
a=20
b=7

print(f"{a*b}")
print("Mulplied value is:", a*b)
# Out:
#   Cell In[5], line 5
#     print("Mulplied value is:" a*b)
#           ^
# SyntaxError: invalid syntax. Perhaps you forgot a comma?
